# %%
from coinmarketcap import *
from core import *
import sys
sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname('__file__')))) #상위 경로 추가 
from util.gateio_coins import *

# %%
volume_coin  =  ['DOGE_USDT', 'NEAR_USDT', 'XTZ_USDT', 'SUSHI_USDT', 'MANA_USDT', 'POLC_USDT', 'KDA_USDT', 'WEMIX_USDT', 'ENJ_USDT', 'RNDR_USDT', 'UOS_USDT', 'SUPER_USDT', 'EGLD_USDT', 'FLUX_USDT', 'QNT_USDT', 'YGG_USDT', 'ZEN_USDT', 'THETA_USDT', 'STX_USDT', 'SHILL_USDT', 'ANY_USDT', 'RAM_USDT', 'RFOX_USDT', 'CAKE_USDT', 'XAVA_USDT', 'HBAR_USDT', 'PBR_USDT', 'REVO_USDT', 'LPT_USDT', 'ILV_USDT', 'CRU_USDT', 'AR_USDT', 'BOBA_USDT', 'ANT_USDT', 'ZKS_USDT', 'BAT_USDT', 'JOE_USDT', 'STORJ_USDT', 'ERN_USDT', 'EPIK_USDT', 'LSS_USDT', 'HNT_USDT', 'LTO_USDT', 'FIS_USDT', 'SYS_USDT', 'BNX_USDT', 'NFTB_USDT', 'NULS_USDT', 'CVX_USDT', 'YFI_USDT', 'BRKL_USDT', 'CGG_USDT', 'PIXEL_USDT', 'FEAR_USDT', 'GAIA_USDT', 'NKN_USDT', 'UNFI_USDT', 'POOLZ_USDT', 'MDX_USDT', 'SOV_USDT', 'UNO_USDT', 'ROOK_USDT', 'CVP_USDT', 'SHI_USDT', 'KP3R_USDT', 'POLK_USDT', 'QUICK_USDT', 'POG_USDT', 'HYDRA_USDT', 'XCUR_USDT', 'BAGS_USDT', 'XVS_USDT', 'KTN_USDT', 'WOOP_USDT', 'MAHA_USDT', 'JFI_USDT', 'GNO_USDT', 'CORN_USDT', 'SYN_USDT', 'KFC_USDT', 'ORAI_USDT', 'PROM_USDT', 'BAS_USDT', 'PICKLE_USDT', 'CLV_USDT', 'XDC_USDT', 'IOI_USDT', 'CWS_USDT', 'TORN_USDT', 'FIRO_USDT', 'UNCX_USDT', 'LYXE_USDT', 'HAPI_USDT', 'MAT_USDT', 'SPI_USDT', 'SUP_USDT', 'ENS_USDT', 'BOSON_USDT', 'METIS_USDT', 'AUCTION_USDT', 'WNXM_USDT', 'BENQI_USDT', 'BEEFI_USDT', 'SLM_USDT']
coin_data = checkAPI_info( [ coin_cap_id[key] for key in volume_coin ])
# print(coin_data)

# %%
word = {}
for key in volume_coin :
    tag = coin_data['data'][str(coin_cap_id[key])]['tags']
    print(key, tag)
    # print(coin_data['data'][str(coin_cap_id[key])]['urls']['twitter'])
    if tag is not None :
        for _t in tag : 
            if _t not in word.keys():
                word[_t] = 1 
            else :
                word[_t] += 1 
# word
# Out:
# DOGE_USDT ['mineable', 'pow', 'scrypt', 'medium-of-exchange', 'memes', 'payments', 'binance-smart-chain', 'doggone-doggerel']
# NEAR_USDT ['platform', 'staking', 'binance-smart-chain', 'coinbase-ventures-portfolio', 'arrington-xrp-capital-portfolio', 'coinfund-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'kenetic-capital-portfolio', 'near-protocol-ecosystem', 'k300-ventures-portfolio']
# XTZ_USDT ['pos', 'platform', 'enterprise-solutions', 'collectibles-nfts', 'defi', 'smart-contracts', 'binance-smart-chain', 'polychain-capital-portfolio', 'boostvc-portfolio', 'winklevoss-capital-portfolio']
# ...

# %%
pgm_lang_val_reverse = sorted(word.items(), reverse=True, key=lambda item: item[1])

for key, value in pgm_lang_val_reverse:
    print(key, ":", value)
# Out:
# binance-smart-chain : 34
# collectibles-nfts : 28
# defi : 25
# metaverse : 18
# gaming : 15
# platform : 13
# web3 : 13
# yield-farming : 12
# play-to-earn : 12
# polygon-ecosystem : 11
# enterprise-solutions : 9
# mineable : 8
# decentralized-exchange : 8
# payments : 7
# avalanche-ecosystem : 7
# dao : 6
# amm : 6
# governance : 6
# fantom-ecosystem : 6
# dcg-portfolio : 6
# polkadot-ecosystem : 6
# pow : 5
# arrington-xrp-capital-portfolio : 5
# yearn-partnerships : 5
# ethereum-ecosystem : 5
# launchpad : 5
# polkastarter : 5
# exnetwork-capital-portfolio : 5
# distributed-computing : 5
# blockchain-capital-portfolio : 4
# alameda-research-portfolio : 4
# entertainment : 4
# polkadot : 4
# multicoin-capital-portfolio : 4
# animoca-brands-portfolio : 4
# dao-maker : 4
# yield-aggregator : 4
# medium-of-exchange : 3
# coinfund-portfolio : 3
# fabric-ventures-portfolio : 3
# kenetic-capital-portfolio : 3
# boostvc-portfolio : 3
# pantera-capital-portfolio : 3
# scaling : 3
# ...

# %%
'DOGE_USDT', 'NEAR_USDT', 'XTZ_USDT', 'SUSHI_USDT', 'MANA_USDT', 'POLC_USDT', 'KDA_USDT', 'CRV_USDT', 'WEMIX_USDT', 'ENJ_USDT', 'RNDR_USDT', 'UOS_USDT', 'SUPER_USDT', 'EGLD_USDT', 'FLUX_USDT', 'YGG_USDT', 'ZEN_USDT', 'THETA_USDT', 'STX_USDT', 'SHILL_USDT', 'MIR_USDT', 'ANY_USDT', 'RFOX_USDT', 'CAKE_USDT', 'XAVA_USDT', 'HBAR_USDT', 'PBR_USDT', 'REVO_USDT', 'BLOCK_USDT', 'LPT_USDT', 'ILV_USDT', 'CRU_USDT', 'AR_USDT', 'ANT_USDT', 'BAT_USDT', 'JOE_USDT', 'BEAM_USDT', 'XCH_USDT', 'STORJ_USDT', 'EPIK_USDT', 'LSS_USDT', 'HNT_USDT', 'CFX_USDT', 'LTO_USDT', 'SYS_USDT', 'NFTB_USDT', 'NULS_USDT', 'CVX_USDT', 'YFI_USDT', 'BRKL_USDT', '10SET_USDT', 'CGG_USDT', 'BADGER_USDT', 'FEAR_USDT', 'DEGO_USDT', 'WICC_USDT', 'SOV_USDT', 'UNO_USDT', 'ROOK_USDT', 'MOBI_USDT', 'CVP_USDT', 'SHI_USDT', 'KP3R_USDT', 'POLK_USDT', 'QUICK_USDT', 'HYDRA_USDT', 'HARD_USDT', 'DREP_USDT', 'INSUR_USDT', 'ARRR_USDT', 'KTN_USDT', 'WOOP_USDT', 'MAHA_USDT', 'GNO_USDT', 'KFC_USDT', 'ORAI_USDT', 'FX_USDT', 'PROM_USDT', 'XDC_USDT', 'IOI_USDT', 'CWS_USDT', 'FIRO_USDT', 'ARCX_USDT', 'PRQ_USDT', 'LYXE_USDT', 'SPI_USDT', 'SKU_USDT', 'ENS_USDT', 'BOSON_USDT', 'METIS_USDT', 'AUCTION_USDT', 'LOCG_USDT', 'WNXM_USDT', 'YFII_USDT', 'DEVT_USDT', 'BEEFI_USDT', 'SLM_USDT'
